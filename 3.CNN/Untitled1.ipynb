# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
path='dogs-vs-cats/train'

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.5*')
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
#from PIL import Image

plt.figure(figsize=(12,8))    
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))        
plt.show()

# %%
#from PIL import Image

plt.figure(figsize=(12,8))    
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))        
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X = np.concatenate((dogs,cats), axis=0)
y = np.concatenate((y_dogs, y_cats), axis=0)

# not encoding
_y = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X)
# Out:
# 2222

# %%
## One-Hot Encoding



# y = tf.keras.utils.to_categorical(y, 2)

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    #Dense(2, activation='softmax')
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 18,940,385
# Trainable params: 18,940,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.compile(loss='categorical_crossentropy', 
#               optimizer=Adam(), metrics=['accuracy'])

model.compile(loss='binary_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])

# %%
## to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
#early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %%
# model.fit(X, y, batch_size=32, epochs=40, validation_split=0.2,
#           callbacks=[checkpointer, early_stopping_callback])

model.fit(X, _y, batch_size=32, epochs=40, validation_split=0.2)
          #,callbacks=[checkpointer, early_stopping_callback])
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.7242 - accuracy: 0.6213 - val_loss: 1.1204 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6624 - accuracy: 0.6258 - val_loss: 0.7312 - val_accuracy: 0.2517
# Epoch 3/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6434 - accuracy: 0.6488 - val_loss: 0.9741 - val_accuracy: 0.1416
# Epoch 4/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6337 - accuracy: 0.6550 - val_loss: 0.7283 - val_accuracy: 0.3348
# Epoch 5/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6332 - accuracy: 0.6607 - val_loss: 1.0677 - val_accuracy: 0.1461
# Epoch 6/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6233 - accuracy: 0.6719 - val_loss: 0.9387 - val_accuracy: 0.1236
# Epoch 7/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6075 - accuracy: 0.6764 - val_loss: 0.7225 - val_accuracy: 0.3865
# Epoch 8/40
# 1777/1777 [==============================] - 29s 16ms/sample - loss: 0.5846 - accuracy: 0.6911 - val_loss: 0.7790 - val_accuracy: 0.2966
# Epoch 9/40
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.5616 - accuracy: 0.7046 - val_loss: 0.8747 - val_accuracy: 0.3056
# Epoch 10/40
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.5182 - accuracy: 0.7299 - val_loss: 1.0228 - val_accuracy: 0.3551
# Epoch 11/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.4864 - accuracy: 0.7563 - val_loss: 0.9706 - val_accuracy: 0.4517
# Epoch 12/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.4403 - accuracy: 0.7895 - val_loss: 1.4246 - val_accuracy: 0.3258
# Epoch 13/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.3369 - accuracy: 0.8509 - val_loss: 1.0470 - val_accuracy: 0.4607
# Epoch 14/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.2597 - accuracy: 0.8891 - val_loss: 1.4660 - val_accuracy: 0.5124
# Epoch 15/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.2061 - accuracy: 0.9150 - val_loss: 1.6490 - val_accuracy: 0.5101
# Epoch 16/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.1470 - accuracy: 0.9465 - val_loss: 1.7187 - val_accuracy: 0.5101
# Epoch 17/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0908 - accuracy: 0.9690 - val_loss: 2.3996 - val_accuracy: 0.4270
# Epoch 18/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0751 - accuracy: 0.9730 - val_loss: 2.1980 - val_accuracy: 0.5348
# Epoch 19/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0650 - accuracy: 0.9719 - val_loss: 2.6441 - val_accuracy: 0.5191
# Epoch 20/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0613 - accuracy: 0.9848 - val_loss: 2.2148 - val_accuracy: 0.5438
# Epoch 21/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0474 - accuracy: 0.9848 - val_loss: 2.1908 - val_accuracy: 0.5416
# Epoch 22/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0366 - accuracy: 0.9904 - val_loss: 2.8534 - val_accuracy: 0.5169
# Epoch 23/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0198 - accuracy: 0.9944 - val_loss: 3.0068 - val_accuracy: 0.5326
# Epoch 24/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0332 - accuracy: 0.9899 - val_loss: 3.2920 - val_accuracy: 0.4607
# Epoch 25/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0332 - accuracy: 0.9904 - val_loss: 3.1729 - val_accuracy: 0.4787
# Epoch 26/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0296 - accuracy: 0.9910 - val_loss: 3.3080 - val_accuracy: 0.4854
# Epoch 27/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0359 - accuracy: 0.9893 - val_loss: 2.6219 - val_accuracy: 0.4854
# Epoch 28/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0165 - accuracy: 0.9961 - val_loss: 3.3052 - val_accuracy: 0.4809
# Epoch 29/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0175 - accuracy: 0.9949 - val_loss: 2.8490 - val_accuracy: 0.5326
# Epoch 30/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0093 - accuracy: 0.9977 - val_loss: 3.4022 - val_accuracy: 0.4652
# Epoch 31/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0167 - accuracy: 0.9944 - val_loss: 3.5796 - val_accuracy: 0.4449
# Epoch 32/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0178 - accuracy: 0.9961 - val_loss: 3.0363 - val_accuracy: 0.5011
# Epoch 33/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0207 - accuracy: 0.9955 - val_loss: 3.3431 - val_accuracy: 0.5011
# Epoch 34/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0107 - accuracy: 0.9972 - val_loss: 3.5061 - val_accuracy: 0.4787
# Epoch 35/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0148 - accuracy: 0.9983 - val_loss: 3.5754 - val_accuracy: 0.4831
# Epoch 36/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0114 - accuracy: 0.9944 - val_loss: 4.2548 - val_accuracy: 0.4674
# Epoch 37/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0063 - accuracy: 0.9972 - val_loss: 4.1298 - val_accuracy: 0.4652
# Epoch 38/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0262 - accuracy: 0.9916 - val_loss: 2.6551 - val_accuracy: 0.5528
# Epoch 39/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0184 - accuracy: 0.9955 - val_loss: 3.3046 - val_accuracy: 0.4607
# Epoch 40/40
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0109 - accuracy: 0.9972 - val_loss: 3.5970 - val_accuracy: 0.4494

# %%
from tensorflow.keras.models import load_model
del model
model = load_model('model/dogs_vs_cats-cnn-07-0.7768.hdf5')

# %%
scores = model.evaluate(X, y, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 2222/2222 - 6s - loss: 0.6186 - accuracy: 0.6301
# MODEL ACCURACY: 0.63006
